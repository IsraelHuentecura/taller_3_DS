# %% [markdown]
#   <h1>Tarea 04: Matplotlib & Seaborn</h1>

# %% [markdown]
# <font size='4'>Completar las siguientes tareas:</font>
#
# <hr style="height:2px;border:none;color:#333;background-color:#333;" />

# %% [markdown]
# Importar las siguientes librerías: `matplotlib.pyplot, seaborn, pandas, numpy`

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ## <b>Recrea la siguiente figura</b>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Generar datos para la distribución normal
x = np.linspace(-10, 10, 50)
mu = 0
sigma1 = 3.3
sigma2 = 4.2
y1 = 1.1 * np.exp(-(x - mu)**2 / (2 * sigma1**2))
y2 = np.exp(-(x - mu)**2 / (2 * sigma2**2))

# Crear el gráfico principal sin grid
sns.set_style("white")
fig, ax = plt.subplots(figsize=(8, 6))
ax.grid(False)

# Distribución normal más aplanada (línea punteada con puntos y líneas más grandes)
ax.plot(x, y1, color='red', linewidth=3, linestyle='dashdot', markersize=7, markerfacecolor='red', markeredgecolor='black')

# Distribución normal más amplia (línea sólida con puntos amarillos y líneas delgadas más grandes)
ax.plot(x, y2, color='blue', linewidth=1, marker='o', markersize=9, markerfacecolor='gold', markeredgecolor='black', markeredgewidth=2)

# Configuración adicional del gráfico principal
ax.set_title('Many Plots', fontsize=16)

# Llamar eje x That took a while
ax.set_xlabel('That took a while', fontsize=18)


# Leyendas en formato LaTeX
ax.legend([r'$3e^{-0.25x^2}$', r'$2.8e^{-0.15(x-0.1)^2}$'], fontsize=12)

# Agregar las palabras "cool", "plot" y "bro" en los colores y ubicaciones especificadas
ax.text(-2, 0.5, 'Cool', color='red', fontsize=20, ha='center', va='center')
ax.text(0, 0.4, 'Plot', color='blue', fontsize=20, ha='center', va='center')
ax.text(2, 0.3, 'Bro', color='green', fontsize=20, ha='center', va='center')

# Mostrar el gráfico
plt.show()

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo el gráfico desaparecerá.

# %% [markdown]
#   <hr style="height:3px;border:none;color:#333;background-color:#333;" />
#
#  <font size='4'> Para el resto de los ejercicios se deb usar el dataset Airbnb contenido en el archivo Airbnb.xlsx.</font>
#
# <h4> <b> Lee y guarda el dataset como `abnb`</b>

# %%
#Ingresa tu código aquí
abnb = pd.read_excel('./data/Airbnb.xlsx')

# %% [markdown]
# ## <b>Revisa el head de los datos:</b>

# %%
#Ingresa tu código aquí
abnb.head()
# Out:
#    Unnamed: 0 neighbourhood_group       neighbourhood        room_type  price
# 0       33941              Queens           Ridgewood  Entire home/apt    280  \
# 1       21257           Manhattan    Theater District     Private room    195
# 2       23462            Brooklyn            Bushwick     Private room     65
# 3       29123            Brooklyn  Bedford-Stuyvesant  Entire home/apt    126
# 4       16774           Manhattan      Hell's Kitchen  Entire home/apt    199
#
#    minimum_nights  number_of_reviews last_review
# 0               2                 40  2019-06-24
# 1               1                  9  2018-12-16
# 2               5                 20  2019-04-21
# 3               1                  9  2018-03-02
# 4              30                  4  2018-03-31

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo la tabla desaparecerá.
# Out:
#    Unnamed: 0 neighbourhood_group       neighbourhood        room_type  price  \
# 0       33941              Queens           Ridgewood  Entire home/apt    280
# 1       21257           Manhattan    Theater District     Private room    195
# 2       23462            Brooklyn            Bushwick     Private room     65
# 3       29123            Brooklyn  Bedford-Stuyvesant  Entire home/apt    126
# 4       16774           Manhattan      Hell's Kitchen  Entire home/apt    199
#
#    minimum_nights  number_of_reviews last_review
# 0               2                 40  2019-06-24
# 1               1                  9  2018-12-16
# 2               5                 20  2019-04-21
# 3               1                  9  2018-03-02
# 4              30                  4  2018-03-31

# %% [markdown]
# ## <b> Recrea el siguiente `jointplot` </b>

# %%
#Ingresa tu código aquí
df = abnb

# Establecer el estilo de los gráficos de Seaborn
sns.set(style='white')

# Crear el jointplot con distribución y mapa de calor
sns.jointplot(data=df, x='number_of_reviews', y='price', kind='kde', color='skyblue', cmap='Blues', fill=True, edgecolor='blue')


# Mostrar el gráfico
plt.show()
# Out:
# c:\Users\Niko\Desktop\repos universidad\Taller_4\venv\lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'edgecolor'
#   cset = contour_func(

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo el gráfico desaparecerá.

# %% [markdown]
# ## <b> Recrea los siguientes `boxplots` </b>

# %%
#Ingresa tu código aquí

# Establecer el estilo de los gráficos de Seaborn
sns.set(style='whitegrid')

# Crear el boxplot
sns.boxplot(data=df, x='neighbourhood_group', y='price')
# Nombra el eje y
plt.ylabel('Price')
# Nombra el eje x
plt.xlabel('Neighbourhood Group')
# Sacar lineas horizontales tipo grid
plt.grid(False)
# Ajustar la rotación de las etiquetas del eje x
plt.xticks(rotation=45)

# Mostrar el gráfico
plt.show()

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo el gráfico desaparecerá.
# Out:
# Text(0, 0.5, 'Price')

# %%
#Ingresa tu código aquí
df = abnb
# Establecer el estilo de los gráficos de Seaborn
sns.set(style='whitegrid')

# Crear el boxplot
sns.boxplot(data=df, x='neighbourhood_group', y='number_of_reviews', hue='room_type')
# Sacar lineas horizontales tipo grid
plt.grid(False)
# Añadir la leyenda
plt.legend(title='Room Type')
# Agrandar el gráfico
plt.gcf().set_size_inches(9, 6)

# Mostrar el gráfico
plt.show()

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo el gráfico desaparecerá.
# Out:
# Text(0, 0.5, 'Number of Reviews')

# %% [markdown]
# ## <b> Recrea el siguiente  `violinplot` comparando la distribución de  `Entire home/apt` y `Private room` para los 5 `neighbourhood groups`</b>

# %%
#Ingresa tu código aquí


df = abnb

# Establecer el estilo de los gráficos de Seaborn
sns.set(style='whitegrid')

# Filtrar el DataFrame para tener solo dos niveles para room_type
df_filtered = df[df['room_type'].isin(['Entire home/apt', 'Private room'])]

# Crear el violinplot
sns.violinplot(data=df_filtered, x='neighbourhood_group', y='price', hue='room_type', split=True)

# Ajustar la leyenda
plt.legend(title='Room Type')

# Mostrar el gráfico
plt.show()

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo el gráfico desaparecerá.
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ## <b>Time Series: Recrea el siguiente gráfico</b>
#
# (Pista: Convierte la columna `last_review` a formato `DateTime`)

# %%
#Ingresa tu código aquí

df = abnb
# Convertir la columna 'last_review' al tipo de datos datetime
df['last_review'] = pd.to_datetime(df['last_review'])
# Dejar datos desde el 2016-10 hasta el 2019-04
df = df[(df['last_review'] >= '2016-10') & (df['last_review'] <= '2019-04')]

# Ordenar el DataFrame por la columna 'last_review'
df = df.sort_values('last_review')

# Crear la gráfica de serie de tiempo
plt.figure(figsize=(10, 6))

plt.plot(df['last_review'], df['number_of_reviews'], label='Number of Reviews')
plt.plot(df['last_review'], df['price'], label='Price')

# Establecer los títulos y etiquetas de los ejes
plt.title('Fluctuations in Number of Reviews and Price over time')
# nombrar el eje x
plt.xlabel('last_review')

# Añadir una leyenda
plt.legend()

# Mostrar la gráfica
plt.show()

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo el gráfico desaparecerá.
